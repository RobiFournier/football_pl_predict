# %%
import pandas as pd
import numpy as np

# %%
fb_ref_html = pd.read_html("https://fbref.com/en/comps/9/Premier-League-Stats")

# %%
for idx, table in enumerate(fb_ref_html):
    print("**********************************************")
    print(idx)
    print(table)
# Out:
# **********************************************
# 0
#     Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1  Manchester City   7  5  2  0  23   6  17   17    2.43  15.7   3.4
# 1    2        Tottenham   7  5  2  0  18   7  11   17    2.43  11.7   7.1
# 2    3          Arsenal   6  5  0  1  14   7   7   15    2.50  11.8   4.9
# 3    4         Brighton   6  4  1  1  11   5   6   13    2.17  10.2   7.1
# 4    5   Manchester Utd   6  4  0  2   8   8   0   12    2.00   8.1   8.4
# 5    6           Fulham   7  3  2  2  12  11   1   11    1.57   8.7  12.0
# 6    7          Chelsea   6  3  1  2   8   9  -1   10    1.67   7.6   6.9
# 7    8        Liverpool   6  2  3  1  15   6   9    9    1.50  12.2   6.7
# 8    9        Brentford   6  2  3  1  15   9   6    9    1.50  10.2   7.7
# 9   10    Newcastle Utd   7  1  5  1   8   7   1    8    1.14  11.4   8.2
# 10  11     Leeds United   6  2  2  2  10  10   0    8    1.33   9.4   8.3
# ...

# %%
fb_ref_html[0]
# Out:
#     Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1  Manchester City   7  5  2  0  23   6  17   17    2.43  15.7   3.4
# 1    2        Tottenham   7  5  2  0  18   7  11   17    2.43  11.7   7.1
# 2    3          Arsenal   6  5  0  1  14   7   7   15    2.50  11.8   4.9
# 3    4         Brighton   6  4  1  1  11   5   6   13    2.17  10.2   7.1
# 4    5   Manchester Utd   6  4  0  2   8   8   0   12    2.00   8.1   8.4
# 5    6           Fulham   7  3  2  2  12  11   1   11    1.57   8.7  12.0
# 6    7          Chelsea   6  3  1  2   8   9  -1   10    1.67   7.6   6.9
# 7    8        Liverpool   6  2  3  1  15   6   9    9    1.50  12.2   6.7
# 8    9        Brentford   6  2  3  1  15   9   6    9    1.50  10.2   7.7
# 9   10    Newcastle Utd   7  1  5  1   8   7   1    8    1.14  11.4   8.2
# 10  11     Leeds United   6  2  2  2  10  10   0    8    1.33   9.4   8.3
# 11  12      Bournemouth   7  2  2  3   6  19 -13    8    1.14   3.3  12.2
# ...

# %%
fb_ref_html[1].droplevel(0, axis=1)
# Out:
#     Rk            Squad  MP  W  D  L  GF  GA  GD  Pts  ...  L  GF  GA  GD  \
# 0    1  Manchester City   3  3  0  0  14   2  12    9  ...  0   9   4   5
# 1    2        Tottenham   4  4  0  0  13   4   9   12  ...  0   5   3   2
# 2    3          Arsenal   3  3  0  0   8   4   4    9  ...  1   6   3   3
# 3    4         Brighton   3  2  1  0   6   2   4    7  ...  1   5   3   2
# 4    5   Manchester Utd   3  2  0  1   6   4   2    6  ...  1   2   4  -2
# 5    6           Fulham   3  2  1  0   7   5   2    7  ...  2   5   6  -1
# 6    7          Chelsea   3  2  1  0   6   4   2    7  ...  2   2   5  -3
# 7    8        Liverpool   3  2  1  0  12   2  10    7  ...  1   3   4  -1
# 8    9        Brentford   3  2  1  0  10   3   7    7  ...  1   5   6  -1
# 9   10    Newcastle Utd   4  1  3  0   6   4   2    6  ...  1   2   3  -1
# 10  11     Leeds United   3  2  1  0   6   2   4    7  ...  2   4   8  -4
# 11  12      Bournemouth   3  1  1  1   2   3  -1    4  ...  2   4  16 -12
# ...

# %%
man_u_stats = pd.read_html("https://fbref.com/en/squads/19538871/Manchester-United-Stats")

# %%
man_u_stats[0].droplevel(0, axis=1)
# Out:
#                 Player   Nation    Pos     Age  MP  Starts    Min  90s  Gls  \
# 0         David de Gea   es ESP     GK  31-316   6       6  540.0  6.0  0.0
# 1      Bruno Fernandes   pt POR  MF,FW  28-011   6       6  539.0  6.0  1.0
# 2          Diogo Dalot   pt POR     DF  23-185   6       6  535.0  5.9  0.0
# 3    Christian Eriksen   dk DEN  MF,FW  30-217   6       6  530.0  5.9  0.0
# 4      Marcus Rashford  eng ENG     FW  24-323   6       6  520.0  5.8  3.0
# 5    Lisandro Martínez   ar ARG     DF  24-244   6       6  484.0  5.4  0.0
# 6         Jadon Sancho  eng ENG     FW  22-178   6       6  418.0  4.6  2.0
# 7      Scott McTominay  sct SCO     MF  25-285   6       5  482.0  5.4  0.0
# 8       Tyrell Malacia   nl NED     DF  23-033   6       4  406.0  4.5  0.0
# 9       Raphaël Varane   fr FRA     DF  29-147   5       4  405.0  4.5  0.0
# 10      Anthony Elanga   se SWE     FW  20-145   5       3  214.0  2.4  0.0
# ...
